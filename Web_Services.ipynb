# %% [markdown]
# - 와이어 포맷 (Wire Format)
# - XML
# - JSON
#
#
#
#
# XML : eXtensible Markup Language의 약자
#
# 다음과 같은 계층 구조
#
#
# ```
# <person>
#   <name>Chuck</name>
#   <phone type="intl">
#      +1 734 303 4456
#    </phone>
#    <email hide="yes" />
# </person>
#
# ```
#
#
# > HTML과 비슷, but 원하는 이름의 태그를 만들 수 있음
#
# > HTML보다 문법 오류를 더 엄격하게 다룸
